# %% [markdown]
# ## Uni-T Multimeter Testing

# %%
import numpy as np
import matplotlib.pyplot as plt
import logging
from qil_ut61eplus.ut61eplus import UT61EPLUS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 import matplotlib.pyplot as plt
#       3 import logging
# ----> 4 from qil_Ut61eplus.ut61eplus import UT61EPLUS
#
# ModuleNotFoundError: No module named 'qil_Ut61eplus'

# %%
log = logging.getLogger(__name__)

logging.basicConfig(level=logging.DEBUG)

dmm = UT61EPLUS()

log.info('name=%s', dmm.getName())
dmm.sendCommand('lamp')
m = dmm.takeMeasurement()
log.info('measurent=%s', m)
